# %%
import pandas as pd
from bokeh.charts import Area, show, output_notebook

# %%
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="d2408a1b-f9ea-449e-9290-6f3f22de3655">Loading BokehJS ...</span>
#     </div>

# %%
df_betas = pd.read_pickle('df_beta.pkl')
df_tickers = pd.read_pickle('df_tickers.pkl')
